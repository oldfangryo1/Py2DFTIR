# %%
from Librarytest import hogehoge
x=1
hogehoge.hello(x)
# Out:
# Hello

# %%
import Librarytest
x=1
Librarytest.hogehoge.hello(x)
# Out:
# Hello

# %%
from Librarytest import test2
x=1
test2.testtt(x,pix=10)
# Out:
# 99

# %%
300**2
# Out:
# 90000

# %%
from Py2DFTIR import Read_tiffimage
import matplotlib.pyplot as plt
file = "/run/media/koga/RKHisaki/2DFT-IR/data/20220520_170047_01/"

x1,y1,z1 = Read_tiffimage.tiffr(file)
plt.contourf(x1,y1,z1[400,:,:])
plt.colorbar()
plt.show()
# Out:
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# ...

# %%
z1.shape[2]
# Out:
# 640

# %%
from Py2DFTIR import FFTVAv1
Zspec,Awav = FFTVAv1.FFTimage(z1)
plt.contourf(x1,y1,Zspec[300,:,:])
plt.colorbar()
plt.show()
# Out:
# 100%|██████████| 512/512 [02:18<00:00,  3.69it/s]

# %%
from Py2DFTIR import Read_tiffimage
import matplotlib.pyplot as plt
#file = "/run/media/koga/RKHisaki/2DFT-IR/data/20220520_170047_01/"
file = "/run/media/koga/RKHisaki/2DFT-IR/data/Li/051_tgt_20230306-A_CZT&10.6-LensStander-filament-Cryostat-11.5v8/20230306_182214_01/20230306_182214_01/"
x1,y1,z1 = Read_tiffimage.tiffr(file)
plt.contourf(x1,y1,z1[400,:,:])
plt.colorbar()
plt.show()
# Out:
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# ...

# %%
from Py2DFTIR import FFTVAv1
Zspec,Awav = FFTVAv1.FFTimage(z1)
plt.contourf(x1,y1,Zspec[300,:,:])
plt.colorbar()
plt.show()
# Out:
# 100%|██████████| 512/512 [02:14<00:00,  3.80it/s]
